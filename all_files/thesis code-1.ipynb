# %%
import re
from google.colab import drive

drive.mount('/content/drive')



def detect_comments_methods(file_path):
    with open(file_path, 'r') as file:
        content = file.read()

    # Regular expressions to detect comments and methods
    comment_pattern = r'#.*'
    method_pattern = r'def\s+(\w+)\s*\((.*?)\):'

    # Find all comments in the file
    comments = re.findall(comment_pattern, content)

    # Find all methods and their parameters
    methods = re.findall(method_pattern, content)
    # Calculate comment percentage
    total_lines = len(content.split('\n'))
    comment_lines = len(comments)
    comment_percentage = (comment_lines / total_lines) * 100

    return comments, methods, comment_percentage

# Example usage:
file_path = '/content/drive/MyDrive/thesis/test4.py'
comments, methods, comment_percentage = detect_comments_methods(file_path)

print("Comments:")
for comment in comments:
    print(comment)

print("\nMethods:")
for method_name, method_params in methods:
    print(f"{method_name}({method_params})")

print("\nComment Percentage:", comment_percentage)
# Out:
# Mounted at /content/drive
# Comments:
# # This is a sample Python file
# # It contains a few methods and comments
# # This method adds two numbers and returns the result
# # This method subtracts two numbers and returns the result
# # This method multiplies two numbers and returns the result
# # This is the main method
# # Call the methods and print the results
#
# Methods:
# add_numbers(a, b)
# subtract_numbers(a, b)
# multiply_numbers(a, b)
#
# Comment Percentage: 33.33333333333333

# %%
import re
import pandas as pd
from google.colab import drive

drive.mount('/content/drive')


def detect_comments_methods(file_path):
    with open(file_path, 'r') as file:
        content = file.read()

    # Regular expressions to detect comments and methods
    comment_pattern = r'#.*'
    method_pattern = r'def\s+(\w+)\s*\((.*?)\):'

    # Find all comments in the file
    comments = re.findall(comment_pattern, content)

    # Find all methods and their parameters
    methods = re.findall(method_pattern, content)

    # Calculate comment percentage
    total_lines = len(content.split('\n'))
    comment_lines = len(comments)
    comment_percentage = (comment_lines / total_lines) * 100

    return comments, methods, comment_percentage

# Example usage:
file_path = '/content/drive/MyDrive/thesis/test4.py'
comments, methods, comment_percentage = detect_comments_methods(file_path)

# Create a list of dictionaries to store the data
data = []
max_len = max(len(comments), len(methods))
for i in range(max_len):
    comment = comments[i] if i < len(comments) else ''
    method = f"{methods[i][0]}({methods[i][1]})" if i < len(methods) else ''
    data.append({
        'Comments': comment,
        'Methods': method,
        'Comment Percentage': comment_percentage,
    })

# Create the DataFrame from the list of dictionaries
df = pd.DataFrame(data)

# Write the DataFrame to an Excel file
output_file_path =  '/content/drive/MyDrive/thesis/sheet.xlsx'
df.to_excel(output_file_path, index=False)

print("Output written to Excel file:", output_file_path)
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).
